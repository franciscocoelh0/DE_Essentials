# %%
# %load_ext sql

# %%
import os
os.environ.get("DBHOST")

# %%
# %env DATABASE_URL=postgresql://itversity_retail_user:itversity@localhost:5432/itversity_retail_db
# Out:
# env: DATABASE_URL=postgresql://itversity_retail_user:itversity@localhost:5432/itversity_retail_db

# %%
# %env DATABASE_URL
# Out:
# 'postgresql://itversity_retail_user:itversity@localhost:5432/itversity_retail_db'

# %%
# %env DB_HOST=localhost
# Out:
# env: DB_HOST=localhost

# %%
# %%sql
#
# select * FROM orders LIMIT 10;
# Out:
# 10 rows affected.
# [(1, datetime.datetime(2013, 7, 25, 0, 0), 11599, 'CLOSED'),
#  (2, datetime.datetime(2013, 7, 25, 0, 0), 256, 'PENDING_PAYMENT'),
#  (3, datetime.datetime(2013, 7, 25, 0, 0), 12111, 'COMPLETE'),
#  (4, datetime.datetime(2013, 7, 25, 0, 0), 8827, 'CLOSED'),
#  (5, datetime.datetime(2013, 7, 25, 0, 0), 11318, 'COMPLETE'),
#  (6, datetime.datetime(2013, 7, 25, 0, 0), 7130, 'COMPLETE'),
#  (7, datetime.datetime(2013, 7, 25, 0, 0), 4530, 'COMPLETE'),
#  (8, datetime.datetime(2013, 7, 25, 0, 0), 2911, 'PROCESSING'),
#  (9, datetime.datetime(2013, 7, 25, 0, 0), 5657, 'PENDING_PAYMENT'),
#  (10, datetime.datetime(2013, 7, 25, 0, 0), 5648, 'PENDING_PAYMENT')]

# %%
import pandas as pd

# %%
help(pd.read_sql)
# Out:
# Help on function read_sql in module pandas:
#
# read_sql(
#     sql,
#     con,
#     index_col: 'str | list[str] | None' = None,
#     coerce_float: 'bool' = True,
#     params=None,
#     parse_dates=None,
#     columns: 'list[str] | None' = None,
#     chunksize: 'int | None' = None,
#     dtype_backend: 'DtypeBackend | lib.NoDefault' = <no_default>,
#     dtype: 'DtypeArg | None' = None
# ) -> 'DataFrame | Iterator[DataFrame]'
#     Read SQL query or database table into a DataFrame.
#
#     This function is a convenience wrapper around ``read_sql_table`` and
#     ``read_sql_query`` (for backward compatibility). It will delegate
#     to the specific function depending on the provided input. A SQL query
#     will be routed to ``read_sql_query``, while a database table name will
#     be routed to ``read_sql_table``. Note that the delegated function might
#     have more specific notes about their functionality not listed here.
#
#     Parameters
#     ----------
# ...

# %%
conn_uri = 'postgresql://itversity_retail_user:itversity@localhost:5432/itversity_retail_db'

# %%
pd.read_sql('orders', conn_uri)
# Out:
#        order_id order_date  order_customer_id     order_status
# 0             1 2013-07-25              11599           CLOSED
# 1             2 2013-07-25                256  PENDING_PAYMENT
# 2             3 2013-07-25              12111         COMPLETE
# 3             4 2013-07-25               8827           CLOSED
# 4             5 2013-07-25              11318         COMPLETE
# ...         ...        ...                ...              ...
# 68878     68879 2014-07-09                778         COMPLETE
# 68879     68880 2014-07-13               1117         COMPLETE
# 68880     68881 2014-07-19               2518  PENDING_PAYMENT
# 68881     68882 2014-07-22              10000          ON_HOLD
# 68882     68883 2014-07-23               5533         COMPLETE
#
# [68883 rows x 4 columns]

# %%
query = '''SELECT * FROM orders LIMIT 10'''

# %%
pd.read_sql(query, conn_uri)
# Out:
#    order_id order_date  order_customer_id     order_status
# 0         1 2013-07-25              11599           CLOSED
# 1         2 2013-07-25                256  PENDING_PAYMENT
# 2         3 2013-07-25              12111         COMPLETE
# 3         4 2013-07-25               8827           CLOSED
# 4         5 2013-07-25              11318         COMPLETE
# 5         6 2013-07-25               7130         COMPLETE
# 6         7 2013-07-25               4530         COMPLETE
# 7         8 2013-07-25               2911       PROCESSING
# 8         9 2013-07-25               5657  PENDING_PAYMENT
# 9        10 2013-07-25               5648  PENDING_PAYMENT

# %%
# %%sql
#
# DROP TABLE IF EXISTS orders CASCADE
# Out:
#  * postgresql://itversity_retail_user:***@localhost:5432/itversity_retail_db
# Done.
# []

# %%
pd.read_sql(query, conn_uri)
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, order_customer_id, order_status]
# Index: []

# %%
import pandas as pd

# %%
# Get the metada (column names)
def get_column_names(schemas, ds_name, sorting_key='column_position'):
    column_details = schemas[ds_name]
    columns = sorted(column_details, key=lambda col: col[sorting_key])
    return [col['column_name'] for col in columns]

# %%
import json

# %%
schemas = json.load(open('retail_db/schemas.json'))

# %%
columns = get_column_names(schemas, 'orders')

# %%
ds_name = 'orders'

# %%
df_reader = pd.read_csv(f'retail_db/{ds_name}/part-00000', names=columns, chunksize=10000)

# %%
df_reader

# %%
type(df)
# Out:
# pandas.io.parsers.readers.TextFileReader

# %%
df_list = list(df_reader)

# %%
df_list[1]
# Out:
#        order_id             order_date  order_customer_id     order_status
# 10000     10001  2013-09-25 00:00:00.0                316  PENDING_PAYMENT
# 10001     10002  2013-09-25 00:00:00.0               1530         COMPLETE
# 10002     10003  2013-09-25 00:00:00.0               8099         COMPLETE
# 10003     10004  2013-09-25 00:00:00.0               7768           CLOSED
# 10004     10005  2013-09-25 00:00:00.0                541         COMPLETE
# ...         ...                    ...                ...              ...
# 19995     19996  2013-11-25 00:00:00.0              11161  PENDING_PAYMENT
# 19996     19997  2013-11-25 00:00:00.0               1920         COMPLETE
# 19997     19998  2013-11-25 00:00:00.0              11672       PROCESSING
# 19998     19999  2013-11-25 00:00:00.0              10014         COMPLETE
# 19999     20000  2013-11-25 00:00:00.0                974  PENDING_PAYMENT
#
# [10000 rows x 4 columns]

# %%
df_list[-1]
# Out:
#        order_id             order_date  order_customer_id     order_status
# 60000     60001  2013-10-20 00:00:00.0               1376         COMPLETE
# 60001     60002  2013-10-20 00:00:00.0               6345  PENDING_PAYMENT
# 60002     60003  2013-10-20 00:00:00.0                329       PROCESSING
# 60003     60004  2013-10-20 00:00:00.0              10907          PENDING
# 60004     60005  2013-10-20 00:00:00.0               5156         COMPLETE
# ...         ...                    ...                ...              ...
# 68878     68879  2014-07-09 00:00:00.0                778         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0               2518  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0              10000          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0               5533         COMPLETE
#
# [8883 rows x 4 columns]

# %%
for idx, df in enumerate(df_list): # enumerate gives us the index and the value of the list while avoiding to manage counters (idx)
    print(f'Chunk {idx} has {len(df)} rows')
# Out:
# Chunk 0 has 10000 rows
# Chunk 1 has 10000 rows
# Chunk 2 has 10000 rows
# Chunk 3 has 10000 rows
# Chunk 4 has 10000 rows
# Chunk 5 has 10000 rows
# Chunk 6 has 8883 rows

# %%
for idx, df in enumerate(df_list):
    print(f'Processing chunck {idx} with size {df.shape[0]} of {ds_name}')
    df.to_sql(
        'orders',
        conn_uri,
        if_exists='append',
        index=False
    )
# Out:
# Processing chunck 0 with size 10000 of orders
# Processing chunck 1 with size 10000 of orders
# Processing chunck 2 with size 10000 of orders
# Processing chunck 3 with size 10000 of orders
# Processing chunck 4 with size 10000 of orders
# Processing chunck 5 with size 10000 of orders
# Processing chunck 6 with size 8883 of orders

# %%
pd.read_sql('orders', conn_uri)
# Out:
#         order_id             order_date  order_customer_id     order_status
# 0              1  2013-07-25 00:00:00.0              11599           CLOSED
# 1              2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2              3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3              4  2013-07-25 00:00:00.0               8827           CLOSED
# 4              5  2013-07-25 00:00:00.0              11318         COMPLETE
# ...          ...                    ...                ...              ...
# 137761     68879  2014-07-09 00:00:00.0                778         COMPLETE
# 137762     68880  2014-07-13 00:00:00.0               1117         COMPLETE
# 137763     68881  2014-07-19 00:00:00.0               2518  PENDING_PAYMENT
# 137764     68882  2014-07-22 00:00:00.0              10000          ON_HOLD
# 137765     68883  2014-07-23 00:00:00.0               5533         COMPLETE
#
# [137766 rows x 4 columns]

# %%
help(pd.read_sql_query)
# Out:
# Help on function read_sql_query in module pandas:
#
# read_sql_query(
#     sql,
#     con,
#     index_col: 'str | list[str] | None' = None,
#     coerce_float: 'bool' = True,
#     params: 'list[Any] | Mapping[str, Any] | None' = None,
#     parse_dates: 'list[str] | dict[str, str] | dict[str, dict[str, Any]] | None' = None,
#     chunksize: 'int | None' = None,
#     dtype: 'DtypeArg | None' = None,
#     dtype_backend: 'DtypeBackend | lib.NoDefault' = <no_default>
# ) -> 'DataFrame | Iterator[DataFrame]'
#     Read SQL query into a DataFrame.
#
#     Returns a DataFrame corresponding to the result set of the query
#     string. Optionally provide an `index_col` parameter to use one of the
#     columns as the index, otherwise default integer index will be used.
#
#     Parameters
#     ----------
#     sql : str SQL query or SQLAlchemy Selectable (select or text object)
#         SQL query to be executed.
#     con : SQLAlchemy connectable, str, or sqlite3 connection
# ...

# %%
df.to_sql('orders', conn_uri, if_exists='replace', index=False)
# Out:
# 883

# %%
pd.read_sql('orders', conn_uri)
