# %%
import pandas as pd

# %%
df = pd.read_csv(
    '/Users/franciscocoelho/VSCodeProjects/franciscocoelh0/Random_Scripts/DE_Essentials/apps/file-to-db-loader/data/retail_db/orders/part-00000',
    names=['order_id', 'order_date', 'order_customer_id', 'order_status']
    
)

# %%
df.shape
# Out:
# (68883, 4)

# %%
conn_uri = 'postgresql://itversity_retail_user:itversity@localhost:5432/itversity_retail_db'

# %%
df.to_sql(
    'orders',
    conn_uri,
    if_exists='append',
    index=False,
    chunksize=10000
    # One Insert statement per row
    #method='none'
    # One Insert statement per chunk [bulk/ batch insert] - if you don't specify chuncksize, there will be one insert statement
    #method='multi' 
    # Method can tune the performance of the to_sql method, you have to experiment.
    )
# Out:
# 6883

# %%
l = [1,2,3,2,4,2,3,5,3,2]

# %%
len(l)
# Out:
# 10

# %%
import time

# %%
for i in l:
    print(f'Sleeping for {i} seconds')
    time.sleep(i)
# Out:
# Sleeping for 1 seconds
# Sleeping for 2 seconds
# Sleeping for 3 seconds
# Sleeping for 2 seconds
# Sleeping for 4 seconds
# Sleeping for 2 seconds
# Sleeping for 3 seconds
# Sleeping for 5 seconds
# Sleeping for 3 seconds
# Sleeping for 2 seconds

# %%
sum(l)
# Out:
# 27

# %%
import multiprocessing

# %%
pool = multiprocessing.Pool(4)

# %%
pool.map(time.sleep, l)
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
from mpdemo import mySleep

# %%
mySleep(2)
# Out:
# Sleeping for 2 seconds

# %%
pool.map(mySleep, l)
# Out:
# Sleeping for 1 seconds
# Sleeping for 2 seconds
# Sleeping for 3 secondsSleeping for 5 seconds
#
# Sleeping for 2 seconds
# Sleeping for 4 secondsSleeping for 2 seconds
#
# Sleeping for 3 seconds
# Sleeping for 3 seconds
# Sleeping for 2 seconds
# [None, None, None, None, None, None, None, None, None, None]

# %%
from multiprocessing_app import process_files

# %%
# The datasets are skwed, so the processing time of each file is different, but we are using the same pool of processes to process all files, so we are not getting the full potential of multiprocessing. 
# We need to use a different pool of processes for each file, but that would be too much overhead. 
# So we need to use a different approach, we can use a queue to store the files that need to be processed and a pool of processes to process the files in the queue. 
# This way we can get the full potential of multiprocessing without the overhead of creating a new pool of processes for each file.
process_files()
# Out:
# Processing departments
# Populating chunk 0 of departments
# Data Processing of departments is complete
# Processing categories
# Populating chunk 0 of categories
# Data Processing of categories is complete
# Processing orders
# Populating chunk 0 of orders
# Populating chunk 1 of orders
# Populating chunk 2 of orders
# Populating chunk 3 of orders
# Populating chunk 4 of orders
# Populating chunk 5 of orders
# Populating chunk 6 of orders
# Data Processing of orders is complete
# Processing products
# Populating chunk 0 of products
# Data Processing of products is complete
# Processing customers
# Populating chunk 0 of customers
# Populating chunk 1 of customers
# Data Processing of customers is complete
# Processing order_items
# Populating chunk 0 of order_items
# Populating chunk 1 of order_items
# Populating chunk 2 of order_items
# Populating chunk 3 of order_items
# Populating chunk 4 of order_items
# Populating chunk 5 of order_items
# Populating chunk 6 of order_items
# ...
