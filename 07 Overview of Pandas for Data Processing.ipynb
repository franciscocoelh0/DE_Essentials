# %% [markdown]
# #Overview of Pandas for Data Processing
#
# Let us get an overview of Python Pandas Library.
#
# - Pandas is one of the most popular libraries of Python.
# - Usage: Data Processing, Data Analysis (including Visualization)
# - Robust APIs to read data from different sources, process data and write data to different targets.
# - Integrated with File Formats, Databases, REST APIs, etc
# - Easy to integrate with additional File Systems or Databases (install additional libraries)

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
pd.

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas:
#
# read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     *,
#     sep: 'str | None | lib.NoDefault' = <no_default>,
#     delimiter: 'str | None | lib.NoDefault' = None,
#     header: "int | Sequence[int] | None | Literal['infer']" = 'infer',
#     names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>,
#     index_col: 'IndexLabel | Literal[False] | None' = None,
#     usecols: 'UsecolsArgType' = None,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters: 'Mapping[HashableT, Callable] | None' = None,
#     true_values: 'list | None' = None,
#     false_values: 'list | None' = None,
#     skipinitialspace: 'bool' = False,
#     skiprows: 'list[int] | int | Callable[[Hashable], bool] | None' = None,
#     skipfooter: 'int' = 0,
#     nrows: 'int | None' = None,
# ...

# %%
pd.read_csv('/Users/franciscocoelho/VSCodeProjects/franciscocoelh0/Random_Scripts/data/retail_db/customers/part-00000.txt')
# Out:
#            1  2013-07-25 00:00:00.0  11599           CLOSED
# 0          2  2013-07-25 00:00:00.0    256  PENDING_PAYMENT
# 1          3  2013-07-25 00:00:00.0  12111         COMPLETE
# 2          4  2013-07-25 00:00:00.0   8827           CLOSED
# 3          5  2013-07-25 00:00:00.0  11318         COMPLETE
# 4          6  2013-07-25 00:00:00.0   7130         COMPLETE
# ...      ...                    ...    ...              ...
# 68877  68879  2014-07-09 00:00:00.0    778         COMPLETE
# 68878  68880  2014-07-13 00:00:00.0   1117         COMPLETE
# 68879  68881  2014-07-19 00:00:00.0   2518  PENDING_PAYMENT
# 68880  68882  2014-07-22 00:00:00.0  10000          ON_HOLD
# 68881  68883  2014-07-23 00:00:00.0   5533         COMPLETE
#
# [68882 rows x 4 columns]

# %%
pd.read_csv('/Users/franciscocoelho/VSCodeProjects/franciscocoelh0/Random_Scripts/data/retail_db/orders/part-00000.txt', header=None)
# Out:
#            0                      1      2                3
# 0          1  2013-07-25 00:00:00.0  11599           CLOSED
# 1          2  2013-07-25 00:00:00.0    256  PENDING_PAYMENT
# 2          3  2013-07-25 00:00:00.0  12111         COMPLETE
# 3          4  2013-07-25 00:00:00.0   8827           CLOSED
# 4          5  2013-07-25 00:00:00.0  11318         COMPLETE
# ...      ...                    ...    ...              ...
# 68878  68879  2014-07-09 00:00:00.0    778         COMPLETE
# 68879  68880  2014-07-13 00:00:00.0   1117         COMPLETE
# 68880  68881  2014-07-19 00:00:00.0   2518  PENDING_PAYMENT
# 68881  68882  2014-07-22 00:00:00.0  10000          ON_HOLD
# 68882  68883  2014-07-23 00:00:00.0   5533         COMPLETE
#
# [68883 rows x 4 columns]

# %%
order_columns = ['order_id', 'order_date', 'order_customer_id', 'order_status']

# %%
pd.read_csv(
    '/Users/franciscocoelho/VSCodeProjects/franciscocoelh0/Random_Scripts/data/retail_db/orders/part-00000.txt',
    header=None, # No need for this as we are providing column names
    names=order_columns)
# Out:
#        order_id             order_date  order_customer_id     order_status
# 0             1  2013-07-25 00:00:00.0              11599           CLOSED
# 1             2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2             3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827           CLOSED
# 4             5  2013-07-25 00:00:00.0              11318         COMPLETE
# ...         ...                    ...                ...              ...
# 68878     68879  2014-07-09 00:00:00.0                778         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0               2518  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0              10000          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0               5533         COMPLETE
#
# [68883 rows x 4 columns]

# %%
orders = pd.read_csv(
    '/Users/franciscocoelho/VSCodeProjects/franciscocoelh0/Random_Scripts/data/retail_db/orders/part-00000.txt', 
    names=order_columns)

# %%
orders.columns
# Out:
# Index(['order_id', 'order_date', 'order_customer_id', 'order_status'], dtype='str')

# %%
help(orders.query)
# Out:
# Help on method query in module pandas.core.frame:
#
# query(
#     expr: 'str',
#     *,
#     parser: "Literal['pandas', 'python']" = 'pandas',
#     engine: "Literal['python', 'numexpr'] | None" = None,
#     local_dict: 'dict[str, Any] | None' = None,
#     global_dict: 'dict[str, Any] | None' = None,
#     resolvers: 'list[Mapping] | None' = None,
#     level: 'int' = 0,
#     inplace: 'bool' = False
# ) -> 'DataFrame | None' method of pandas.DataFrame instance
#     Query the columns of a DataFrame with a boolean expression.
#
#     .. warning::
#
#         This method can run arbitrary code which can make you vulnerable to code
#         injection if you pass user input to this function.
#
#     Parameters
#     ----------
#     expr : str
#         The query string to evaluate.
#
#         See the documentation for :func:`eval` for details of
#         supported operations and functions in the query string.
#
# ...

# %%
orders['order_status']
# Out:
# 0                 CLOSED
# 1        PENDING_PAYMENT
# 2               COMPLETE
# 3                 CLOSED
# 4               COMPLETE
#               ...
# 68878           COMPLETE
# 68879           COMPLETE
# 68880    PENDING_PAYMENT
# 68881            ON_HOLD
# 68882           COMPLETE
# Name: order_status, Length: 68883, dtype: str

# %%
orders['order_status'].unique()
# Out:
# <StringArray>
# [         'CLOSED', 'PENDING_PAYMENT',        'COMPLETE',      'PROCESSING',
#   'PAYMENT_REVIEW',         'PENDING',         'ON_HOLD',        'CANCELED',
#  'SUSPECTED_FRAUD']
# Length: 9, dtype: str

# %%
orders.query('order_status == "COMPLETE"')
# Out:
#        order_id             order_date  order_customer_id order_status
# 2             3  2013-07-25 00:00:00.0              12111     COMPLETE
# 4             5  2013-07-25 00:00:00.0              11318     COMPLETE
# 5             6  2013-07-25 00:00:00.0               7130     COMPLETE
# 6             7  2013-07-25 00:00:00.0               4530     COMPLETE
# 14           15  2013-07-25 00:00:00.0               2568     COMPLETE
# ...         ...                    ...                ...          ...
# 68875     68876  2014-07-06 00:00:00.0               4124     COMPLETE
# 68877     68878  2014-07-08 00:00:00.0               6753     COMPLETE
# 68878     68879  2014-07-09 00:00:00.0                778     COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117     COMPLETE
# 68882     68883  2014-07-23 00:00:00.0               5533     COMPLETE
#
# [22899 rows x 4 columns]

# %%
round(orders.describe())
# Out:
#        order_id  order_customer_id
# count   68883.0            68883.0
# mean    34442.0             6217.0
# std     19885.0             3586.0
# min         1.0                1.0
# 25%     17222.0             3122.0
# 50%     34442.0             6199.0
# 75%     51662.0             9326.0
# max     68883.0            12435.0

# %%
orders.query('order_status == "COMPLETE" and order_date == "2014-01-01 00:00:00.0"')
# Out:
#        order_id             order_date  order_customer_id order_status
# 25881     25882  2014-01-01 00:00:00.0               4598     COMPLETE
# 25887     25888  2014-01-01 00:00:00.0               6735     COMPLETE
# 25888     25889  2014-01-01 00:00:00.0              10045     COMPLETE
# 25894     25895  2014-01-01 00:00:00.0               1044     COMPLETE
# 25896     25897  2014-01-01 00:00:00.0               6405     COMPLETE
# 25897     25898  2014-01-01 00:00:00.0               3950     COMPLETE
# 25900     25901  2014-01-01 00:00:00.0               3099     COMPLETE
# 25901     25902  2014-01-01 00:00:00.0               6083     COMPLETE
# 25906     25907  2014-01-01 00:00:00.0               3603     COMPLETE
# 25912     25913  2014-01-01 00:00:00.0               9382     COMPLETE
# 25913     25914  2014-01-01 00:00:00.0               9288     COMPLETE
# 25914     25915  2014-01-01 00:00:00.0               2963     COMPLETE
# ...

# %%
orders.query('order_status == "COMPLETE" or order_status == "CLOSED"')
# Out:
#        order_id             order_date  order_customer_id order_status
# 0             1  2013-07-25 00:00:00.0              11599       CLOSED
# 2             3  2013-07-25 00:00:00.0              12111     COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827       CLOSED
# 4             5  2013-07-25 00:00:00.0              11318     COMPLETE
# 5             6  2013-07-25 00:00:00.0               7130     COMPLETE
# ...         ...                    ...                ...          ...
# 68875     68876  2014-07-06 00:00:00.0               4124     COMPLETE
# 68877     68878  2014-07-08 00:00:00.0               6753     COMPLETE
# 68878     68879  2014-07-09 00:00:00.0                778     COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117     COMPLETE
# 68882     68883  2014-07-23 00:00:00.0               5533     COMPLETE
#
# [30455 rows x 4 columns]

# %%
orders.query('order_status == ("COMPLETE", "CLOSED")')
# Out:
#        order_id             order_date  order_customer_id order_status
# 0             1  2013-07-25 00:00:00.0              11599       CLOSED
# 2             3  2013-07-25 00:00:00.0              12111     COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827       CLOSED
# 4             5  2013-07-25 00:00:00.0              11318     COMPLETE
# 5             6  2013-07-25 00:00:00.0               7130     COMPLETE
# ...         ...                    ...                ...          ...
# 68875     68876  2014-07-06 00:00:00.0               4124     COMPLETE
# 68877     68878  2014-07-08 00:00:00.0               6753     COMPLETE
# 68878     68879  2014-07-09 00:00:00.0                778     COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117     COMPLETE
# 68882     68883  2014-07-23 00:00:00.0               5533     COMPLETE
#
# [30455 rows x 4 columns]

# %%
orders['order_status'].value_counts()
# Out:
# order_status
# COMPLETE           22899
# PENDING_PAYMENT    15030
# PROCESSING          8275
# PENDING             7610
# CLOSED              7556
# ON_HOLD             3798
# SUSPECTED_FRAUD     1558
# CANCELED            1428
# PAYMENT_REVIEW       729
# Name: count, dtype: int64

# %%
orders.groupby('order_status')

# %%
type(orders.groupby('order_status'))
# Out:
# pandas.api.typing.DataFrameGroupBy

# %%
orders.groupby('order_status').count()
# Out:
#                  order_id  order_date  order_customer_id
# order_status
# CANCELED             1428        1428               1428
# CLOSED               7556        7556               7556
# COMPLETE            22899       22899              22899
# ON_HOLD              3798        3798               3798
# PAYMENT_REVIEW        729         729                729
# PENDING              7610        7610               7610
# PENDING_PAYMENT     15030       15030              15030
# PROCESSING           8275        8275               8275
# SUSPECTED_FRAUD      1558        1558               1558

# %%
orders.groupby('order_status').agg('count')
# Out:
#                  order_id  order_date  order_customer_id
# order_status
# CANCELED             1428        1428               1428
# CLOSED               7556        7556               7556
# COMPLETE            22899       22899              22899
# ON_HOLD              3798        3798               3798
# PAYMENT_REVIEW        729         729                729
# PENDING              7610        7610               7610
# PENDING_PAYMENT     15030       15030              15030
# PROCESSING           8275        8275               8275
# SUSPECTED_FRAUD      1558        1558               1558

# %%
orders.groupby('order_status')['order_id'].agg('count')
# Out:
# order_status
# CANCELED            1428
# CLOSED              7556
# COMPLETE           22899
# ON_HOLD             3798
# PAYMENT_REVIEW       729
# PENDING             7610
# PENDING_PAYMENT    15030
# PROCESSING          8275
# SUSPECTED_FRAUD     1558
# Name: order_id, dtype: int64

# %%
orders.groupby('order_status')['order_id'].agg(order_status ='count')
# Out:
#                  order_status
# order_status
# CANCELED                 1428
# CLOSED                   7556
# COMPLETE                22899
# ON_HOLD                  3798
# PAYMENT_REVIEW            729
# PENDING                  7610
# PENDING_PAYMENT         15030
# PROCESSING               8275
# SUSPECTED_FRAUD          1558

# %% [markdown]
# Getting order_month from order_date is a row level transformation

# %%
orders['order_month'] = orders['order_date'].str.slice(5, 7)

# %%
orders.head()
# Out:
#    order_id             order_date  order_customer_id     order_status  \
# 0         1  2013-07-25 00:00:00.0              11599           CLOSED
# 1         2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2         3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3         4  2013-07-25 00:00:00.0               8827           CLOSED
# 4         5  2013-07-25 00:00:00.0              11318         COMPLETE
#
#   order_month
# 0          07
# 1          07
# 2          07
# 3          07
# 4          07

# %%
orders['order_year'] = orders['order_date'].str.slice(0, 4)

# %%
orders['order_day'] = orders['order_date'].str.slice(8, 10)

# %%
orders.head()
# Out:
#    order_id             order_date  order_customer_id     order_status  \
# 0         1  2013-07-25 00:00:00.0              11599           CLOSED
# 1         2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2         3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3         4  2013-07-25 00:00:00.0               8827           CLOSED
# 4         5  2013-07-25 00:00:00.0              11318         COMPLETE
#
#   order_month order_year order_day
# 0          07       2013        25
# 1          07       2013        25
# 2          07       2013        25
# 3          07       2013        25
# 4          07       2013        25

# %%
orders['order_lambda_month'] = orders.apply(lambda order: order.order_date[0:7], axis=1) # axis=1 means that the function is applied to each row

# %%
orders.head()
# Out:
#    order_id             order_date  order_customer_id     order_status  \
# 0         1  2013-07-25 00:00:00.0              11599           CLOSED
# 1         2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2         3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3         4  2013-07-25 00:00:00.0               8827           CLOSED
# 4         5  2013-07-25 00:00:00.0              11318         COMPLETE
#
#   order_month order_year order_day order_lambda_month
# 0          07       2013        25            2013-07
# 1          07       2013        25            2013-07
# 2          07       2013        25            2013-07
# 3          07       2013        25            2013-07
# 4          07       2013        25            2013-07

# %%
orders.groupby('order_lambda_month', 'order_status')['order_id'].agg(order_status ='count')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 order.groupby('order_lambda_month', 'order_status')['order_id'].agg(order_status ='count')
#
# NameError: name 'order' is not defined

# %% [markdown]
# It failed because the content within the groupby is not a list.

# %%
orders. \
    groupby(['order_lambda_month', 'order_status'])['order_id'] \
    .agg(order_status ='count')
# Out:
#                                     order_status
# order_lambda_month order_status
# 2013-07            CANCELED                   22
#                    CLOSED                    161
#                    COMPLETE                  515
#                    ON_HOLD                    81
#                    PAYMENT_REVIEW             19
# ...                                          ...
# 2014-07            PAYMENT_REVIEW             54
#                    PENDING                   517
#                    PENDING_PAYMENT           979
#                    PROCESSING                561
#                    SUSPECTED_FRAUD           101
#
# [117 rows x 1 columns]

# %%
orders. \
    groupby(['order_lambda_month', 'order_status'])['order_id'] \
    .agg(order_count ='count'). \
    reset_index()
# Out:
#     order_lambda_month     order_status  order_count
# 0              2013-07         CANCELED           22
# 1              2013-07           CLOSED          161
# 2              2013-07         COMPLETE          515
# 3              2013-07          ON_HOLD           81
# 4              2013-07   PAYMENT_REVIEW           19
# ..                 ...              ...          ...
# 112            2014-07   PAYMENT_REVIEW           54
# 113            2014-07          PENDING          517
# 114            2014-07  PENDING_PAYMENT          979
# 115            2014-07       PROCESSING          561
# 116            2014-07  SUSPECTED_FRAUD          101
#
# [117 rows x 3 columns]

# %% [markdown]
# # Joining Data in Pandas Dataframes
#
# Here are the steps involved in joining data using Pandas Dataframe APIs.
#
#  - First, we need to define index for both the dataframes that are supposed to be joined.
#  - Use join to join the Dataframes based on index. The default join is left, we need to make sure right join is used based on the requirement.
#
# In our case, we will join orders and customers using inner join.

# %%
import json

# %%
import pandas as pd

# %% [markdown]
# The json document has multiple items their values are JSON arrays.

# %%
def get_column_names(schemas, table_name, sorting_key='column_position'):
    column_details = schemas[table_name]
    ## return column_details
    columns = sorted(column_details, key=lambda col: col[sorting_key])
    ##return columns
    return [col['column_name'] for col in columns]

# %%
schemas = json.load(open('/Users/franciscocoelho/VSCodeProjects/franciscocoelh0/Random_Scripts/data/retail_db/schemas.json'))

# %%
order_columns = get_column_names(schemas, 'orders')

# %%
order_columns
# Out:
# ['order_id', 'order_date', 'order_customer_id', 'order_status']

# %%
orders = pd.read_csv(
    '/Users/franciscocoelho/VSCodeProjects/franciscocoelh0/Random_Scripts/data/retail_db/orders/part-00000.txt', 
    names = order_columns)

# %%
customer_columns = get_column_names(schemas, 'customers')

# %%
customer_columns = get_column_names(schemas, 'customers')

# %%
customer_columns
# Out:
# ['customer_id',
#  'customer_fname',
#  'customer_lname',
#  'customer_email',
#  'customer_password',
#  'customer_street',
#  'customer_city',
#  'customer_state',
#  'customer_zipcode']

# %%
customers = pd.read_csv(
    '/Users/franciscocoelho/VSCodeProjects/franciscocoelh0/Random_Scripts/data/retail_db/customers/part-00000', 
    names = customer_columns)

# %%
orders
# Out:
#        order_id             order_date  order_customer_id     order_status
# 0             1  2013-07-25 00:00:00.0              11599           CLOSED
# 1             2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2             3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827           CLOSED
# 4             5  2013-07-25 00:00:00.0              11318         COMPLETE
# ...         ...                    ...                ...              ...
# 68878     68879  2014-07-09 00:00:00.0                778         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0               2518  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0              10000          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0               5533         COMPLETE
#
# [68883 rows x 4 columns]

# %%
customers
# Out:
#        customer_id customer_fname customer_lname customer_email  \
# 0                1        Richard      Hernandez      XXXXXXXXX
# 1                2           Mary        Barrett      XXXXXXXXX
# 2                3            Ann          Smith      XXXXXXXXX
# 3                4           Mary          Jones      XXXXXXXXX
# 4                5         Robert         Hudson      XXXXXXXXX
# ...            ...            ...            ...            ...
# 12430        12431           Mary           Rios      XXXXXXXXX
# 12431        12432         Angela          Smith      XXXXXXXXX
# 12432        12433       Benjamin         Garcia      XXXXXXXXX
# 12433        12434           Mary          Mills      XXXXXXXXX
# 12434        12435          Laura         Horton      XXXXXXXXX
#
#       customer_password             customer_street customer_city  \
# 0             XXXXXXXXX          6303 Heather Plaza   Brownsville
# ...

# %%
help(customers.join)
# Out:
# Help on method join in module pandas.core.frame:
#
# join(
#     other: 'DataFrame | Series | Iterable[DataFrame | Series]',
#     on: 'IndexLabel | None' = None,
#     how: 'MergeHow' = 'left',
#     lsuffix: 'str' = '',
#     rsuffix: 'str' = '',
#     sort: 'bool' = False,
#     validate: 'JoinValidate | None' = None
# ) -> 'DataFrame' method of pandas.DataFrame instance
#     Join columns of another DataFrame.
#
#     Join columns with `other` DataFrame either on index or on a key
#     column. Efficiently join multiple DataFrame objects by index at once by
#     passing a list.
#
#     Parameters
#     ----------
#     other : DataFrame, Series, or a list containing any combination of them
#         Index should be similar to one of the columns in this one. If a
#         Series is passed, its name attribute must be set, and that will be
#         used as the column name in the resulting joined DataFrame.
#     on : str, list of str, or array-like, optional
# ...

# %%
customers.set_index('customer_id')
# Out:
#             customer_fname customer_lname customer_email customer_password  \
# customer_id
# 1                  Richard      Hernandez      XXXXXXXXX         XXXXXXXXX
# 2                     Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# 3                      Ann          Smith      XXXXXXXXX         XXXXXXXXX
# 4                     Mary          Jones      XXXXXXXXX         XXXXXXXXX
# 5                   Robert         Hudson      XXXXXXXXX         XXXXXXXXX
# ...                    ...            ...            ...               ...
# 12431                 Mary           Rios      XXXXXXXXX         XXXXXXXXX
# 12432               Angela          Smith      XXXXXXXXX         XXXXXXXXX
# 12433             Benjamin         Garcia      XXXXXXXXX         XXXXXXXXX
# 12434                 Mary          Mills      XXXXXXXXX         XXXXXXXXX
# 12435                Laura         Horton      XXXXXXXXX         XXXXXXXXX
#
# ...

# %%
customers = customers.set_index('customer_id')

# %%
order = orders.set_index('order_customer_id')

# %%
customer_orders = customers. \
join(order, how='inner')

# %%
customer_orders
# Out:
#             customer_fname customer_lname customer_email customer_password  \
# customer_id
# 1                  Richard      Hernandez      XXXXXXXXX         XXXXXXXXX
# 2                     Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# 2                     Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# 2                     Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# 2                     Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# ...                    ...            ...            ...               ...
# 12434                 Mary          Mills      XXXXXXXXX         XXXXXXXXX
# 12434                 Mary          Mills      XXXXXXXXX         XXXXXXXXX
# 12434                 Mary          Mills      XXXXXXXXX         XXXXXXXXX
# 12435                Laura         Horton      XXXXXXXXX         XXXXXXXXX
# 12435                Laura         Horton      XXXXXXXXX         XXXXXXXXX
#
# ...

# %%
customer_orders.shape
# Out:
# (68883, 11)

# %%
customer_test = customers. \
join(order,
     on='customer_id'
     ,how='left')

# %%
customer_test
# Out:
#             customer_fname customer_lname customer_email customer_password  \
# customer_id
# 1                  Richard      Hernandez      XXXXXXXXX         XXXXXXXXX
# 2                     Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# 2                     Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# 2                     Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# 2                     Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# ...                    ...            ...            ...               ...
# 12434                 Mary          Mills      XXXXXXXXX         XXXXXXXXX
# 12434                 Mary          Mills      XXXXXXXXX         XXXXXXXXX
# 12434                 Mary          Mills      XXXXXXXXX         XXXXXXXXX
# 12435                Laura         Horton      XXXXXXXXX         XXXXXXXXX
# 12435                Laura         Horton      XXXXXXXXX         XXXXXXXXX
#
# ...

# %%
customer_orders. \
    reset_index(names='customer_id'). \
    groupby('customer_id')['customer_id']. \
    agg('count')
# Out:
# customer_id
# 1         1
# 2         4
# 3         7
# 4         6
# 5         4
#          ..
# 12431    16
# 12432    10
# 12433     4
# 12434     8
# 12435     2
# Name: customer_id, Length: 12405, dtype: int64

# %%
customer_orders. \
    reset_index(names='customer_id'). \
    groupby('customer_id')['customer_id']. \
    agg(order_count='count'). \
    reset_index(). \
    query('order_count >= 10')
# Out:
#        customer_id  order_count
# 70              71           10
# 171            172           10
# 173            174           12
# 196            197           11
# 219            221           15
# ...            ...          ...
# 12311        12341           10
# 12317        12347           10
# 12375        12406           10
# 12400        12431           16
# 12401        12432           10
#
# [699 rows x 2 columns]

# %%
help(orders.sort_values)
# Out:
# Help on method sort_values in module pandas.core.frame:
#
# sort_values(
#     by: 'IndexLabel',
#     *,
#     axis: 'Axis' = 0,
#     ascending: 'bool | list[bool] | tuple[bool, ...]' = True,
#     inplace: 'bool' = False,
#     kind: 'SortKind' = 'quicksort',
#     na_position: 'str' = 'last',
#     ignore_index: 'bool' = False,
#     key: 'ValueKeyFunc | None' = None
# ) -> 'DataFrame | None' method of pandas.DataFrame instance
#     Sort by the values along either axis.
#
#     Parameters
#     ----------
#     by : str or list of str
#         Name or list of names to sort by.
#
#         - if `axis` is 0 or `'index'` then `by` may contain index
#           levels and/or column labels.
#         - if `axis` is 1 or `'columns'` then `by` may contain column
#           levels and/or index labels.
#     axis : "{0 or 'index', 1 or 'columns'}", default 0
#          Axis to be sorted.
#     ascending : bool or list of bool, default True
# ...

# %%
orders.sort_values('order_customer_id', ascending=False)
# Out:
#        order_id             order_date  order_customer_id     order_status
# 41642     41643  2014-04-08 00:00:00.0              12435          PENDING
# 61628     61629  2013-12-21 00:00:00.0              12435         CANCELED
# 4798       4799  2013-08-23 00:00:00.0              12434  PENDING_PAYMENT
# 5302       5303  2013-08-26 00:00:00.0              12434          PENDING
# 1867       1868  2013-08-03 00:00:00.0              12434           CLOSED
# ...         ...                    ...                ...              ...
# 67862     67863  2013-11-30 00:00:00.0                  2         COMPLETE
# 33864     33865  2014-02-18 00:00:00.0                  2         COMPLETE
# 15191     15192  2013-10-29 00:00:00.0                  2  PENDING_PAYMENT
# 57962     57963  2013-08-02 00:00:00.0                  2          ON_HOLD
# 22944     22945  2013-12-13 00:00:00.0                  1         COMPLETE
#
# [68883 rows x 4 columns]

# %%
orders.sort_values(['order_customer_id', 'order_date'])
# Out:
#        order_id             order_date  order_customer_id     order_status
# 22944     22945  2013-12-13 00:00:00.0                  1         COMPLETE
# 57962     57963  2013-08-02 00:00:00.0                  2          ON_HOLD
# 15191     15192  2013-10-29 00:00:00.0                  2  PENDING_PAYMENT
# 67862     67863  2013-11-30 00:00:00.0                  2         COMPLETE
# 33864     33865  2014-02-18 00:00:00.0                  2         COMPLETE
# ...         ...                    ...                ...              ...
# 61776     61777  2013-12-26 00:00:00.0              12434         COMPLETE
# 42914     42915  2014-04-16 00:00:00.0              12434         COMPLETE
# 51799     51800  2014-06-14 00:00:00.0              12434          ON_HOLD
# 61628     61629  2013-12-21 00:00:00.0              12435         CANCELED
# 41642     41643  2014-04-08 00:00:00.0              12435          PENDING
#
# [68883 rows x 4 columns]

# %%
orders.sort_values(
    ['order_customer_id', 'order_date'],
    ascending=[False, True])
# Out:
#        order_id             order_date  order_customer_id     order_status
# 61628     61629  2013-12-21 00:00:00.0              12435         CANCELED
# 41642     41643  2014-04-08 00:00:00.0              12435          PENDING
# 1867       1868  2013-08-03 00:00:00.0              12434           CLOSED
# 4798       4799  2013-08-23 00:00:00.0              12434  PENDING_PAYMENT
# 5302       5303  2013-08-26 00:00:00.0              12434          PENDING
# ...         ...                    ...                ...              ...
# 57962     57963  2013-08-02 00:00:00.0                  2          ON_HOLD
# 15191     15192  2013-10-29 00:00:00.0                  2  PENDING_PAYMENT
# 67862     67863  2013-11-30 00:00:00.0                  2         COMPLETE
# 33864     33865  2014-02-18 00:00:00.0                  2         COMPLETE
# 22944     22945  2013-12-13 00:00:00.0                  1         COMPLETE
#
# [68883 rows x 4 columns]

# %%
orders.to_csv?
# Out:
# Signature:
# orders.to_csv(
#     path_or_buf: 'FilePath | WriteBuffer[bytes] | WriteBuffer[str] | None' = None,
#     *,
#     sep: 'str' = ',',
#     na_rep: 'str' = '',
#     float_format: 'str | Callable | None' = None,
#     columns: 'Sequence[Hashable] | None' = None,
#     header: 'bool | list[str]' = True,
#     index: 'bool' = True,
#     index_label: 'IndexLabel | None' = None,
#     mode: 'str' = 'w',
#     encoding: 'str | None' = None,
#     compression: 'CompressionOptions' = 'infer',
#     quoting: 'int | None' = None,
#     quotechar: 'str' = '"',
#     lineterminator: 'str | None' = None,
#     chunksize: 'int | None' = None,
#     date_format: 'str | None' = None,
#     doublequote: 'bool' = True,
#     escapechar: 'str | None' = None,
#     decimal: 'str' = '.',
#     errors: 'OpenFileErrors' = 'strict',
#     storage_options: 'StorageOptions | None' = None,
# ) -> 'str | None'
# Docstring:
# Write object to a comma-separated values (csv) file.
#
# Parameters
# ...

# %%
import os

os.makedirs('/Users/franciscocoelho/VSCodeProjects/franciscocoelh0/Random_Scripts/data/retail_db/orders_json', exist_ok=True)

# %%
# Save data using columnar format
orders.to_json('/Users/franciscocoelho/VSCodeProjects/franciscocoelh0/Random_Scripts/data/retail_db/orders_json/part-00000')

# %%
# Save data using row format
orders.to_json('/Users/franciscocoelho/VSCodeProjects/franciscocoelh0/Random_Scripts/data/retail_db/orders_json/part-00000',
                orient='records',
                  lines=True
                  )

# %%
pd.read_json('/Users/franciscocoelho/VSCodeProjects/franciscocoelh0/Random_Scripts/data/retail_db/orders_json/part-00000',lines=True)
# Out:
#        order_id             order_date  order_customer_id     order_status
# 0             1  2013-07-25 00:00:00.0              11599           CLOSED
# 1             2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2             3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827           CLOSED
# 4             5  2013-07-25 00:00:00.0              11318         COMPLETE
# ...         ...                    ...                ...              ...
# 68878     68879  2014-07-09 00:00:00.0                778         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0               2518  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0              10000          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0               5533         COMPLETE
#
# [68883 rows x 4 columns]
